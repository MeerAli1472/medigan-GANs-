# %% [markdown]
# # Using Medigan for Synthetic Medical Image Generation.
# The broader goal is to demonstrate how synthetic medical images can support real-world tasks. When real annotated data is scarce, which is often the case in medical imaging, generated data can be a valuable resource for data augmentation, pretraining, or even system testing
#
# Below we just giving a demostration to show that what kind of images we can expect.
#
# run the below code and click on gradio link, a dashboard will open, designed using gradio(free hosting server). The GUI is friendly.

# %% [markdown]
# ### Install reqyirements

# %%
# prompt: install medigan and gradio
# !pip install medigan
# !pip install gradio

# %% [markdown]
# **Start your app, go to your app page by click on gradio live, and play around with it!**

# %%
# !python app.py
